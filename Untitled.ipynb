# %%
import numpy as np

# %%
b = np.load('ResNetGenerator_850000.npz')

# %%
b

# %%
lst = b.files
for item in lst:
    print(item)
    print(b[item].shape)
# Out:
# block5/c2/b
# (128,)
# block4/b2/betas/W
# (1000, 256)
# block5/b1/gammas/W
# (1000, 256)
# block4/c1/b
# (256,)
# b7/gamma
# (64,)
# block6/c2/b
# (64,)
# block3/b1/gammas/W
# (1000, 1024)
# l7/W
# (3, 64, 3, 3)
# block4/b2/gammas/W
# (1000, 256)
# block3/c_sc/b
# (512,)
# block6/c_sc/W
# (64, 128, 1, 1)
# block3/b2/avg_mean
# (512,)
# l1/b
# (16384,)
# block5/b2/N
# ()
# block2/c_sc/b
# (1024,)
# block2/b2/N
# ()
# block4/b1/avg_mean
# (512,)
# block3/c_sc/W
# (512, 1024, 1, 1)
# b7/avg_var
# (64,)
# block5/c2/W
# (128, 128, 3, 3)
# block3/b2/betas/W
# (1000, 512)
# block2/c2/b
# (1024,)
# block4/b1/betas/W
# (1000, 512)
# block2/c1/b
# (1024,)
# block6/b1/N
# ()
# block5/b1/avg_mean
# (256,)
# block3/b2/avg_var
# (512,)
# b7/beta
# (64,)
# block2/b2/avg_mean
# (1024,)
# block2/b2/avg_var
# (1024,)
# block2/b1/N
# ()
# block6/b2/gammas/W
# (1000, 64)
# block6/c1/b
# (64,)
# block4/b2/avg_var
# (256,)
# block4/c2/W
# (256, 256, 3, 3)
# block2/b2/gammas/W
# (1000, 1024)
# ...
